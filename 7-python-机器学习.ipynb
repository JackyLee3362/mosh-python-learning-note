# %% [markdown]
# # 机器学习
#
# ## 步骤
#
# 1. 导入数据 import the Data
# 2. 清洗数据 Clean the Data
# 3. 分成训练和测试数据 Split the Data into Training / Test Sets
# 4. 建模 Create a Model
# 5. 训练 Train the Model
# 6. 预测 Make Predictions
# 7. 评价和升级 Evaluate and Improve
#
# ## 库和工具
#
# - Numpy
# - Pandas
# - MatPlotLib
# - Scikit-Learn
# - Jupyter
#
# ## 数据集
#
# - www.kaggle.com

# %%
import pandas as pd

df = pd.read_csv('vgsales.csv')
df.shape  # 返回(行数，列数)
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.describe()  # 返回分析数据
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %% [markdown]
# # jupyter快捷键
#
# ## 蓝色-代码模式
#
# - h 打开快捷键面板
# - b 插入代码块
# - dd 删除
#
# ## 绿色-编辑模式
#
# - tab 展示可选项
# - shift+tab 展示详细信息

# %% [markdown]
# # 机器学习（正片开始）
#
# mosh给的网址下载不了，那么我们就用刚刚得数据，df来进行数据处理

# %%
data = df[["Year","Publisher","Global_Sales"]]
print(data)
print(type(data))
# Out:
#          Year   Publisher  Global_Sales
# 0      2006.0    Nintendo         82.74
# 1      1985.0    Nintendo         40.24
# 2      2008.0    Nintendo         35.82
# 3      2009.0    Nintendo         33.00
# 4      1996.0    Nintendo         31.37
# ...       ...         ...           ...
# 16593  2002.0       Kemco          0.01
# 16594  2003.0  Infogrames          0.01
# 16595  2008.0  Activision          0.01
# 16596  2010.0    7G//AMES          0.01
# 16597  2003.0     Wanadoo          0.01
#
# [16598 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
## 清洗数据

data.describe()
X = data.drop(columns=['Global_Sales'])
print(X)
y = data['Global_Sales']
print(y)
# Out:
#          Year   Publisher
# 0      2006.0    Nintendo
# 1      1985.0    Nintendo
# 2      2008.0    Nintendo
# 3      2009.0    Nintendo
# 4      1996.0    Nintendo
# ...       ...         ...
# 16593  2002.0       Kemco
# 16594  2003.0  Infogrames
# 16595  2008.0  Activision
# 16596  2010.0    7G//AMES
# 16597  2003.0     Wanadoo
#
# [16598 rows x 2 columns]
# 0        82.74
# 1        40.24
# 2        35.82
# 3        33.00
# 4        31.37
#          ...
# 16593     0.01
# 16594     0.01
# 16595     0.01
# 16596     0.01
# 16597     0.01
# Name: Global_Sales, Length: 16598, dtype: float64

# %%
# 建模

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X, y)
predictions = model.predict([ [2000, 'Nintendo'], [2009, 'Kemco'] ])
predictions
print(pred)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [28], in <cell line: 3>()
#       1 # 建模
# ----> 3 from sklearn.tree import DecisionTreeClassifier
#       5 model = DecisionTreeClassifier()
#       6 model.fit(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = ['calibration', 'cluster', 'covariance', 'cross_decomposition',
#      86            'datasets', 'decomposition', 'dummy', 'ensemble', 'exceptions',
#      87            'experimental', 'externals', 'feature_extraction',
#    (...)
#      96            'clone', 'get_config', 'set_config', 'config_context',
#      97            'show_versions']
#
# ...
